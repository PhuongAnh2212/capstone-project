# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ue-city-dataset/SemanticClasses.csv
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1206.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_932.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2288.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1416.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1746.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1159.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_767.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1780.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_973.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_930.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_611.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1179.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2153.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_970.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1996.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1559.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_570.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1595.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_111.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1076.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_659.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_406.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_895.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1529.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_430.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1316.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1396.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1515.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1143.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_983.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2216.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_298.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2340.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2229.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_733.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1701.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1087.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2401.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2447.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1237.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_808.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_053.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2330.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_114.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_031.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1503.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_828.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1704.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2112.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1888.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1779.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_177.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2202.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_820.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1539.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2184.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1950.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_334.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2404.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_846.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2183.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_142.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2445.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_959.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1142.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_642.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_445.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2159.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1319.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_458.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1019.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_814.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1999.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_373.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1917.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1393.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_459.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2310.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1580.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_105.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2156.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2420.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1028.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_037.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1893.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_457.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1182.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1079.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_907.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1407.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_689.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2455.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_850.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1176.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_587.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_947.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2106.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1947.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1700.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1369.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_870.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2147.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_911.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_686.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_939.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1923.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1951.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1592.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_525.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1519.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_260.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1329.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1840.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2450.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1445.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2247.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1153.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_104.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2291.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1606.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_560.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_051.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1305.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1866.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2124.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_878.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_742.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1009.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1222.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1355.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_710.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1083.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_785.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1593.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1577.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_961.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1213.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_566.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1637.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1082.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1266.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_819.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1651.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1487.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1650.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_676.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2217.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2094.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2426.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1169.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_155.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_753.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2096.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_077.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_106.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1124.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_342.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_812.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1236.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1968.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2272.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_002.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1063.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_369.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1766.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_384.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1134.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1029.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1496.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_400.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_253.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1430.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_573.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2047.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2145.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2285.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_980.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_606.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2252.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1691.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1953.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_277.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1108.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2243.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_178.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_581.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2309.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_526.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2436.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_823.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1616.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_999.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_648.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_452.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_996.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2079.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_385.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1627.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2040.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1705.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1008.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1315.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_603.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2087.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2346.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_887.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_653.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1734.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_794.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_799.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1155.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1713.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1604.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_018.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1512.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1544.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1322.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2304.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1287.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2400.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2103.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2132.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1313.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1275.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_548.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_620.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_220.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1685.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1348.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2361.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2368.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_579.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2357.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1264.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2161.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2374.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_658.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1770.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1833.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_057.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1135.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1405.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_720.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_470.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2212.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2296.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_562.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1084.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_141.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1978.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1386.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2007.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1290.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1818.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1218.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1915.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_221.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_423.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1196.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1647.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1903.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1786.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_162.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_140.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_506.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1752.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_536.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_885.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_951.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_236.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1563.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2035.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1629.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1568.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_533.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1165.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1347.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1098.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2218.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_505.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_616.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_330.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2418.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2319.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2056.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1095.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_957.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1245.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1675.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1813.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_618.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1659.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_529.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1896.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2347.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_343.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1571.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_242.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2393.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_518.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1991.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1977.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_345.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1094.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1260.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_682.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_788.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1972.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_569.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1321.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_315.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_842.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_994.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_410.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2108.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1832.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1488.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1614.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_929.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_818.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2162.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1992.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2399.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_328.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_765.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_872.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_903.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2131.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_888.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1033.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_415.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1961.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_631.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2122.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1310.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1827.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2344.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1421.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_460.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_361.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1481.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_960.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1483.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_956.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1801.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_891.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1814.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_751.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_519.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1857.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_263.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1821.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1183.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_2241.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_744.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_048.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_933.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_617.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_494.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1875.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_362.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1353.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1796.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_917.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1882.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_643.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_217.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1644.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB/rgb_frame_1748.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_994.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_560.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1310.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1814.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_631.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1996.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2183.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_819.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1977.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2087.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_620.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1748.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1405.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1355.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1888.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1369.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1503.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_263.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1481.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1218.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2217.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1082.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_850.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1704.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_423.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2216.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2218.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_470.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_077.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_037.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2108.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_617.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_814.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_385.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_111.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1496.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_369.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_242.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2399.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1353.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2106.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2243.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2288.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2347.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1947.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_983.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2040.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_142.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_885.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2455.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1134.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2145.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1488.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1347.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_445.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1165.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1322.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1348.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_999.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_430.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1796.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1644.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2285.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_911.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_917.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1568.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1290.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_603.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1275.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1416.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_961.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2346.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_606.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_581.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1915.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1766.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_846.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_452.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2340.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_260.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_767.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1896.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2310.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1019.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1833.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_460.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1196.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1182.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1593.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1972.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_048.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_579.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_799.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2450.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1176.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_676.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1650.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_458.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1213.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_221.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_155.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_328.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1266.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1329.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_536.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_682.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2330.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1519.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_253.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1752.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2418.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_178.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2056.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_494.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1961.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_823.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1571.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_570.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1637.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1917.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2309.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1647.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1779.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_140.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_643.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1563.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2147.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1786.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_361.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_828.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1580.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1999.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1083.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_765.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_872.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1604.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1539.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_932.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1159.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_457.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_018.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1029.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1108.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_031.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1992.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1183.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1734.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_362.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2124.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2229.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1124.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_878.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_957.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_330.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_930.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2252.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1260.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1321.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2436.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1675.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1487.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_973.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1237.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1028.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2344.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_105.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_053.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1430.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1063.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_548.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_177.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2272.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_887.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_2159.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_1153.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic/semantic_frame_659.jpg
# ...
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_159.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1296.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1432.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_908.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_300.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2407.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1371.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1167.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1707.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_432.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2423.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_927.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1740.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1440.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_861.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1721.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2073.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_858.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_241.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1294.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1859.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_417.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1885.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_267.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2377.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1086.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1830.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_647.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1027.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1361.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1753.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2141.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2233.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_877.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_026.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_429.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1007.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_180.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_145.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_938.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_091.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2444.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1053.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_025.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_621.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_046.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_357.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_748.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1403.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1466.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1363.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_012.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1517.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_320.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2221.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_880.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1117.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1528.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2428.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_198.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2195.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_080.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1436.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_479.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1937.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_450.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_645.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1454.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1244.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1397.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_531.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1807.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_426.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1730.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2148.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1219.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1655.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_171.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_251.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_411.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_474.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2023.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_468.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_169.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2334.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_773.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2090.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_821.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1068.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_778.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2137.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_368.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_588.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_281.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2176.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1530.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_912.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2371.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2001.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1687.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1594.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1449.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1408.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1723.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2003.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2271.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2238.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_685.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1605.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_626.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2395.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_119.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1507.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2337.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_261.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1146.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1078.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2107.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2305.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_936.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1784.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_563.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_875.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2068.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_554.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_543.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1928.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1148.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1792.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2138.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_520.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_800.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2008.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1360.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_652.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_677.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2134.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1844.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2432.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2256.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_954.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_709.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2174.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_490.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_349.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1447.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2210.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_507.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2312.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1789.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1652.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_826.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1254.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1251.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1478.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1081.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_420.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_356.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_779.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2240.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1696.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1799.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1049.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2303.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2169.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2092.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_375.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2253.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_471.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1920.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_881.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_172.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_2194.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1224.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_1794.jpg
# /kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Depth/depth_frame_662.jpg

# %%
import torch.optim as optim
from tqdm import tqdm 
import matplotlib.pyplot as plt
import numpy as np
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
from torch.utils.data import Dataset
from PIL import Image
import os

class SemanticSegDataset(Dataset):
    def __init__(self, rgb_dir, mask_dir, rgb_transform=None, mask_transform=None):
        self.rgb_dir = rgb_dir
        self.mask_dir = mask_dir
        self.rgb_transform = rgb_transform
        self.mask_transform = mask_transform
        self.filenames = sorted(os.listdir(rgb_dir))

    def __len__(self):
        return len(self.filenames)

    def __getitem__(self, idx):
        rgb_name = self.filenames[idx]
        rgb_path = os.path.join(self.rgb_dir, rgb_name)
        mask_name = rgb_name.replace("rgb", "semantic")
        mask_path = os.path.join(self.mask_dir, mask_name)

        rgb = Image.open(rgb_path).convert("RGB")
        mask = Image.open(mask_path)

        if self.rgb_transform:
            rgb = self.rgb_transform(rgb)
        if self.mask_transform:
            mask = self.mask_transform(mask)

        return rgb, mask

# %%
import torchvision.transforms as T
from torch.utils.data import DataLoader

rgb_transform = T.Compose([
    T.Resize((512, 512)),
    T.ToTensor(),
])

mask_transform = T.Compose([
    T.Resize((512, 512), interpolation=Image.NEAREST),
    T.PILToTensor(),  # Keeps integer labels
])

train_dataset = SemanticSegDataset("/kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/RGB", "/kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/train/Semantic", rgb_transform, mask_transform)
val_dataset = SemanticSegDataset("/kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/RGB", "/kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/val/Semantic", rgb_transform, mask_transform)

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=4)

# %%
import torchvision.models.segmentation as models
import torch.nn as nn
import torch

NUM_CLASSES = 9  # Change to your actual number of classes

model = models.deeplabv3_resnet50(weights="DEFAULT")
model.classifier[4] = nn.Conv2d(256, NUM_CLASSES, kernel_size=1)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/deeplabv3_resnet50_coco-cd0a2569.pth" to /root/.cache/torch/hub/checkpoints/deeplabv3_resnet50_coco-cd0a2569.pth
# 100%|██████████| 161M/161M [00:00<00:00, 212MB/s]
# DeepLabV3(
#   (backbone): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (classifier): DeepLabHead(
#     (0): ASPP(
#       (convs): ModuleList(
#         (0): Sequential(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (1): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (2): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(24, 24), dilation=(24, 24), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (3): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(36, 36), dilation=(36, 36), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (4): ASPPPooling(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU()
#         )
#       )
#       (project): Sequential(
#         (0): Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Conv2d(256, 9, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (aux_classifier): FCNHead(
#     (0): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=5, verbose=True, min_lr=2e-6)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
class EarlyStopping:
    def __init__(self, patience=20):
        self.patience = patience
        self.counter = 0
        self.best_acc = 0
        self.best_model_wts = None

    def step(self, acc, model):
        if acc > self.best_acc:
            self.best_acc = acc
            self.best_model_wts = model.state_dict()
            self.counter = 0
        else:
            self.counter += 1
        return self.counter >= self.patience

    def restore(self, model):
        if self.best_model_wts:
            model.load_state_dict(self.best_model_wts)

early_stopping = EarlyStopping(patience=20)

# %%
class_colors = {
    "freeway deck": [0, 81, 33],
    "obstacles": [83, 21, 0],
    "traffic light": [0, 89, 254], 
    "decor": [142, 255, 145],
    "margin": [222, 118, 255],
    "building": [255, 239, 3],
    "car": [255, 0, 86],
    "road": [0, 184, 255],
    "sky": [255, 255, 255],
}

color_to_class = {tuple(rgb): idx for idx, (class_name, rgb) in enumerate(class_colors.items())}

def rgb_to_class_indices(batch_rgb_masks, color_to_class):
    batch_class_masks = []
    for rgb_mask in batch_rgb_masks:
        rgb_mask = rgb_mask.transpose(1, 2, 0)  # (C, H, W) to (H, W, C)
        class_mask = np.zeros(rgb_mask.shape[:2], dtype=np.int64)
        for color, class_idx in color_to_class.items():
            mask = np.all(rgb_mask == np.array(color), axis=-1)
            class_mask[mask] = class_idx
        batch_class_masks.append(torch.tensor(class_mask, dtype=torch.long))
    return torch.stack(batch_class_masks)

# %%
def compute_iou_dice(preds, masks, num_classes):
    ious = []
    dices = []
    preds = preds.view(-1)
    masks = masks.view(-1)
    for cls in range(num_classes):
        pred_inds = preds == cls
        target_inds = masks == cls
        intersection = (pred_inds & target_inds).sum().float()
        union = (pred_inds | target_inds).sum().float()
        dice = (2 * intersection) / (pred_inds.sum() + target_inds.sum() + 1e-6)
        iou = intersection / (union + 1e-6)
        if target_inds.sum() > 0: 
            ious.append(iou.item())
            dices.append(dice.item())
    return sum(ious) / len(ious), sum(dices) / len(dices)

# %%
EPOCHS = 10
epoch_losses, epoch_accuracies, val_losses, val_accuracies = [], [], [], []
iou_scores, dice_scores = [], []

for epoch in range(EPOCHS):
    # -------- Training --------
    model.train()
    total_loss = 0
    total_correct = 0
    total_pixels = 0

    for images, rgb_masks in tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS} - Training", unit="batch"):
        images = images.to(device)
        masks = rgb_to_class_indices(rgb_masks.numpy(), color_to_class).to(device)

        outputs = model(images)['out']
        loss = criterion(outputs, masks)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        preds = torch.argmax(outputs, dim=1)
        total_correct += (preds == masks).sum().item()
        total_pixels += masks.numel()

    avg_train_loss = total_loss / len(train_loader)
    train_accuracy = total_correct / total_pixels * 100
    epoch_losses.append(avg_train_loss)
    epoch_accuracies.append(train_accuracy)

    # -------- Validation --------
    model.eval()
    val_loss = 0
    val_correct = 0
    val_total = 0
    total_iou = 0
    total_dice = 0
    num_batches = 0

    with torch.no_grad():
        for images, rgb_masks in tqdm(val_loader, desc="Validating", unit="batch"):
            images = images.to(device)
            masks = rgb_to_class_indices(rgb_masks.numpy(), color_to_class).to(device)

            outputs = model(images)['out']
            loss = criterion(outputs, masks)
            val_loss += loss.item()

            preds = torch.argmax(outputs, dim=1)
            val_correct += (preds == masks).sum().item()
            val_total += masks.numel()

            # Compute IoU and Dice
            iou, dice = compute_iou_dice(preds, masks, NUM_CLASSES)
            total_iou += iou
            total_dice += dice
            num_batches += 1

    avg_val_loss = val_loss / len(val_loader)
    val_accuracy = val_correct / val_total * 100
    avg_iou = total_iou / num_batches
    avg_dice = total_dice / num_batches

    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)
    iou_scores.append(avg_iou)
    dice_scores.append(avg_dice)

    # Scheduler and Early Stopping
    scheduler.step(val_accuracy)
    stop = early_stopping.step(val_accuracy, model)

    print(f"Epoch {epoch+1}/{EPOCHS}, "
          f"Loss: {avg_train_loss:.4f}, Acc: {train_accuracy:.2f}%, "
          f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.2f}%, "
          f"IoU: {avg_iou:.4f}, Dice: {avg_dice:.4f}")

    if stop:
        print("Early stopping triggered.")
        break

early_stopping.restore(model)
plt.figure(figsize=(21, 6))

plt.subplot(1, 3, 1)
plt.plot(range(1, len(epoch_losses)+1), epoch_losses, label='Train Loss', color='red')
plt.plot(range(1, len(val_losses)+1), val_losses, label='Val Loss', color='orange')
plt.title("Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(range(1, len(epoch_accuracies)+1), epoch_accuracies, label='Train Accuracy', color='blue')
plt.plot(range(1, len(val_accuracies)+1), val_accuracies, label='Val Accuracy', color='green')
plt.title("Accuracy over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.grid(True)
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(range(1, len(iou_scores)+1), iou_scores, label='IoU', color='purple')
plt.plot(range(1, len(dice_scores)+1), dice_scores, label='Dice', color='brown')
plt.title("IoU and Dice over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/10 - Training: 100%|██████████| 430/430 [07:03<00:00,  1.02batch/s]
# Validating: 100%|██████████| 93/93 [00:46<00:00,  2.02batch/s]
# Epoch 1/10, Loss: 0.5368, Acc: 85.86%, Val Loss: 0.3065, Val Acc: 89.74%, IoU: 0.5884, Dice: 0.6759
# Epoch 2/10 - Training: 100%|██████████| 430/430 [06:36<00:00,  1.09batch/s]
# Validating: 100%|██████████| 93/93 [00:40<00:00,  2.30batch/s]
# Epoch 2/10, Loss: 0.2692, Acc: 90.60%, Val Loss: 0.2505, Val Acc: 90.79%, IoU: 0.6090, Dice: 0.6935
# Epoch 3/10 - Training: 100%|██████████| 430/430 [06:34<00:00,  1.09batch/s]
# Validating: 100%|██████████| 93/93 [00:39<00:00,  2.33batch/s]
# Epoch 3/10, Loss: 0.2240, Acc: 91.55%, Val Loss: 0.2215, Val Acc: 91.52%, IoU: 0.6274, Dice: 0.7108
# Epoch 4/10 - Training: 100%|██████████| 430/430 [06:35<00:00,  1.09batch/s]
# Validating: 100%|██████████| 93/93 [00:40<00:00,  2.32batch/s]
# Epoch 4/10, Loss: 0.1944, Acc: 92.35%, Val Loss: 0.2137, Val Acc: 91.70%, IoU: 0.6376, Dice: 0.7212
# Epoch 5/10 - Training: 100%|██████████| 430/430 [06:34<00:00,  1.09batch/s]
# Validating: 100%|██████████| 93/93 [00:39<00:00,  2.35batch/s]
# Epoch 5/10, Loss: 0.1891, Acc: 92.46%, Val Loss: 0.1997, Val Acc: 92.09%, IoU: 0.6518, Dice: 0.7357
# Epoch 6/10 - Training: 100%|██████████| 430/430 [06:35<00:00,  1.09batch/s]
# Validating: 100%|██████████| 93/93 [00:40<00:00,  2.31batch/s]
# Epoch 6/10, Loss: 0.1647, Acc: 93.25%, Val Loss: 0.1975, Val Acc: 92.29%, IoU: 0.6564, Dice: 0.7393
# Epoch 7/10 - Training: 100%|██████████| 430/430 [06:35<00:00,  1.09batch/s]
# Validating: 100%|██████████| 93/93 [00:39<00:00,  2.34batch/s]
# Epoch 7/10, Loss: 0.1555, Acc: 93.57%, Val Loss: 0.1972, Val Acc: 92.25%, IoU: 0.6581, Dice: 0.7411
# Epoch 8/10 - Training: 100%|██████████| 430/430 [06:35<00:00,  1.09batch/s]
# Validating: 100%|██████████| 93/93 [00:40<00:00,  2.32batch/s]
# Epoch 8/10, Loss: 0.1453, Acc: 93.95%, Val Loss: 0.1991, Val Acc: 92.34%, IoU: 0.6628, Dice: 0.7450
# Epoch 9/10 - Training: 100%|██████████| 430/430 [06:34<00:00,  1.09batch/s]
# Validating: 100%|██████████| 93/93 [00:39<00:00,  2.33batch/s]
# Epoch 9/10, Loss: 0.1391, Acc: 94.18%, Val Loss: 0.1959, Val Acc: 92.64%, IoU: 0.6670, Dice: 0.7484
# Epoch 10/10 - Training: 100%|██████████| 430/430 [06:34<00:00,  1.09batch/s]
# Validating: 100%|██████████| 93/93 [00:39<00:00,  2.35batch/s]
# Epoch 10/10, Loss: 0.1316, Acc: 94.48%, Val Loss: 0.1967, Val Acc: 92.75%, IoU: 0.6691, Dice: 0.7506

# %%
import torch

# Save model weights
torch.save(model.state_dict(), 'deeplab_weights_v6_10epoch.pth')

# %%
from PIL import Image
import torch
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

model.eval()

rgb_path = "/kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/test/RGB/rgb_frame_1035.jpg"               # ← Update
gt_mask_path = "/kaggle/input/ue-city-dataset/SyntheticData/SyntheticData/test/Semantic/semantic_frame_1035.jpg" # ← Update

# Load RGB and GT mask
image = Image.open(rgb_path).convert("RGB")
gt_mask = Image.open(gt_mask_path).convert("RGB")
original_size = image.size

# Transform
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor()
])

# Process input image
input_tensor = transform(image).unsqueeze(0).to(device)

# Inference
model.eval()
with torch.no_grad():
    output = model(input_tensor)['out']
    pred = torch.argmax(output.squeeze(), dim=0).cpu().numpy()

# Decode prediction
def decode_segmentation(mask, class_colors):
    h, w = mask.shape
    color_mask = np.zeros((h, w, 3), dtype=np.uint8)
    for idx, (class_name, color) in enumerate(class_colors.items()):
        color_mask[mask == idx] = color
    return color_mask

pred_color = decode_segmentation(pred, class_colors)
pred_image_resized = Image.fromarray(pred_color).resize(original_size)

# Plot
plt.figure(figsize=(18, 6))

# Original RGB
plt.subplot(1, 3, 1)
plt.title("Original RGB")
plt.imshow(image)
plt.axis("off")

# Ground Truth
plt.subplot(1, 3, 2)
plt.title("Ground Truth")
plt.imshow(gt_mask)
plt.axis("off")

# Predicted Segmentation
plt.subplot(1, 3, 3)
plt.title("Predicted Segmentation")
plt.imshow(pred_image_resized)
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
model = models.deeplabv3_resnet50(num_classes=9, aux_loss=True)

# Load the full state dict
state_dict = torch.load('deeplab_weights_v6_10epoch.pth')

# Remove classifier heads from the checkpoint
for key in ["classifier.4.weight", "classifier.4.bias",
            "aux_classifier.4.weight", "aux_classifier.4.bias"]:
    if key in state_dict:
        del state_dict[key]

# Load weights with strict=False
model.load_state_dict(state_dict, strict=False)
model.to(device)
# Out:
# /tmp/ipykernel_31/3179876753.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load('deeplab_weights_v6_10epoch.pth')
# DeepLabV3(
#   (backbone): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (classifier): DeepLabHead(
#     (0): ASPP(
#       (convs): ModuleList(
#         (0): Sequential(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (1): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (2): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(24, 24), dilation=(24, 24), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (3): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(36, 36), dilation=(36, 36), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (4): ASPPPooling(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU()
#         )
#       )
#       (project): Sequential(
#         (0): Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Conv2d(256, 9, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (aux_classifier): FCNHead(
#     (0): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(256, 9, kernel_size=(1, 1), stride=(1, 1))
#   )
# )
